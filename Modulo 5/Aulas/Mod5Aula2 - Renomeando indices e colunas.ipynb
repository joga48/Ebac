# %% [markdown]
# # Índice <a name="Contents"></a>
# 1. [Importando bibliotecas](#import)
# 2. [Construindo um dataframe](#read)
# 3. [Renomeando colunas](#colunas)
# 4. [Renomeando índices](#indices)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import pandas as pd
import numpy  as np

# %% [markdown]
# # 2. Construindo um dataframe <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df = pd.DataFrame(
    np.random.randn(9, 4)*100,
    index=["A", "B", "C", "D", "E", "F", "G", "H", "I"],
    columns=["coluna1", "coluna2", "coluna3","coluna4"],
)
df
# Out:
#       coluna1     coluna2     coluna3     coluna4
# A  -15.445218   39.923868  -45.981524   25.111855
# B   56.628993   46.461824  -39.443986   97.637959
# C  -85.799504  -67.451252  141.540134 -149.870228
# D  -41.936396  191.044804  -73.089993  -62.009932
# E   37.318403  -57.793408   24.191080  -81.916567
# F   33.081850  124.300053  206.235583  -98.159691
# G -106.594757    4.048532  -39.070892    7.053601
# H  -78.365559  -51.708112    6.116107   94.565794
# I  109.785841  -24.671219  137.415020  108.210327

# %% [markdown]
# # 3. Renomeando colunas <a name="colunas"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df.columns
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4'], dtype='object')

# %%
df.columns = ['segunda', 'terça', 'quarta', 'quinta']

# %%
df.columns
# Out:
# Index(['segunda', 'terça', 'quarta', 'quinta'], dtype='object')

# %%
df
# Out:
#       segunda       terça      quarta      quinta
# A  -15.445218   39.923868  -45.981524   25.111855
# B   56.628993   46.461824  -39.443986   97.637959
# C  -85.799504  -67.451252  141.540134 -149.870228
# D  -41.936396  191.044804  -73.089993  -62.009932
# E   37.318403  -57.793408   24.191080  -81.916567
# F   33.081850  124.300053  206.235583  -98.159691
# G -106.594757    4.048532  -39.070892    7.053601
# H  -78.365559  -51.708112    6.116107   94.565794
# I  109.785841  -24.671219  137.415020  108.210327

# %% [markdown]
# # 4. Renomeando índices <a name="indices"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
df['coluna5'] = ['letraA','letraB','letraC','letraD','letraE','letraF','letraG','letraH','letraI']

# %%
df
# Out:
#       segunda       terça      quarta      quinta coluna5
# A  -15.445218   39.923868  -45.981524   25.111855  letraA
# B   56.628993   46.461824  -39.443986   97.637959  letraB
# C  -85.799504  -67.451252  141.540134 -149.870228  letraC
# D  -41.936396  191.044804  -73.089993  -62.009932  letraD
# E   37.318403  -57.793408   24.191080  -81.916567  letraE
# F   33.081850  124.300053  206.235583  -98.159691  letraF
# G -106.594757    4.048532  -39.070892    7.053601  letraG
# H  -78.365559  -51.708112    6.116107   94.565794  letraH
# I  109.785841  -24.671219  137.415020  108.210327  letraI

